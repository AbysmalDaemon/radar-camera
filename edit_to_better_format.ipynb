# %% [markdown]
# DELETE COLUMNS

# %%
import os
import pandas as pd

folder_path = 'radar'  # Specify the folder path where the CSV files are located

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Delete the first four columns
        df = df.iloc[:, 4:]
        
        # Save the modified dataframe back to the CSV file
        df.to_csv(file_path, index=False)

# %% [markdown]
# DELETE MORE COLUMNS

# %%
import os
import pandas as pd

folder_path = 'radar'  # Specify the folder path where the CSV files are located
columns_to_delete = ['camera_timestamp', 'closest_radar_timestamp', 'radar_timestamp']

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Delete the specified columns
        df.drop(columns=columns_to_delete, inplace=True)
        
        # Save the modified dataframe back to the CSV file
        df.to_csv(file_path, index=False)

# %% [markdown]
# TRANSPOSE THE CSV FILES

# %%
import os
import csv

# Create a new folder for saving transposed files
output_folder = 'radar_new'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Get the list of CSV files in the 'radar' folder
input_folder = 'radar'
csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]

# Iterate over each CSV file and transpose the data
for file in csv_files:
    input_path = os.path.join(input_folder, file)
    output_path = os.path.join(output_folder, file)

    # Read the CSV file
    with open(input_path, 'r') as csv_file:
        reader = csv.reader(csv_file)
        data = list(reader)

    # Transpose the data
    transposed_data = list(map(list, zip(*data)))

    # Write the transposed data to a new CSV file
    with open(output_path, 'w', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerows(transposed_data)

    print(f"Transposed data saved to: {output_path}")
# Out:
# Transposed data saved to: radar_new\20-20-15.139673_896551.csv
# Transposed data saved to: radar_new\20-20-15.209644_798285.csv
# Transposed data saved to: radar_new\20-20-15.318575_981951.csv
# Transposed data saved to: radar_new\20-20-15.399274_880192.csv
# Transposed data saved to: radar_new\20-20-15.519459_349586.csv
# Transposed data saved to: radar_new\20-20-15.629186_862125.csv
# Transposed data saved to: radar_new\20-20-15.709092_532119.csv
# Transposed data saved to: radar_new\20-20-15.829834_782751.csv
# Transposed data saved to: radar_new\20-20-15.938949_295961.csv
# Transposed data saved to: radar_new\20-20-16.019488_891478.csv
# Transposed data saved to: radar_new\20-20-16.143955_195238.csv
# Transposed data saved to: radar_new\20-20-16.402694_981796.csv
# Transposed data saved to: radar_new\20-20-16.450768_822281.csv
# Transposed data saved to: radar_new\20-20-16.521007_808993.csv
# Transposed data saved to: radar_new\20-20-16.628647_602092.csv
# ...

# %% [markdown]
# REMOVE BRACKETS

# %%
import os
import csv

# Create the 'radar1' folder if it doesn't exist
if not os.path.exists('radar1'):
    os.makedirs('radar1')

# Get a list of all CSV files in the 'radar_new' folder
csv_files = [file for file in os.listdir('radar_new') if file.endswith('.csv')]

# Iterate over each CSV file
for file in csv_files:
    file_path = os.path.join('radar_new', file)
    output_path = os.path.join('radar1', file)
    
    # Open the input CSV file
    with open(file_path, 'r') as input_file:
        reader = csv.reader(input_file)
        rows = list(reader)
        
        # Modify the second column of each row
        for row in rows:
            if len(row) >= 2:
                row[1] = row[1].lstrip('(').rstrip(')')
        
    # Save the modified data to a new CSV file in the 'radar1' folder
    with open(output_path, 'w', newline='') as output_file:
        writer = csv.writer(output_file)
        writer.writerows(rows)

# %% [markdown]
# ADD NEW ROW FOR LABELS

# %%
import os
import csv

# Specify the folder path where the CSV files are located
input_folder_path = "radar"

# Specify the folder path to save the output CSVs
output_folder_path = "radar1"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Get a list of all files in the input folder
file_list = os.listdir(input_folder_path)

# Iterate over each file in the folder
for file_name in file_list:
    if file_name.endswith(".csv"):  # Process only CSV files
        input_file_path = os.path.join(input_folder_path, file_name)
        output_file_path = os.path.join(output_folder_path, file_name)

        # Create a new row with labels and values
        new_row = ['Parameters', 'Values']

        # Read the existing CSV data
        existing_rows = []
        with open(input_file_path, 'r') as file:
            reader = csv.reader(file)
            existing_rows = list(reader)

        # Append the new row on top of the existing rows
        updated_rows = [new_row] + existing_rows

        # Write the updated rows to the output CSV file
        with open(output_file_path, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerows(updated_rows)

# %% [markdown]
# DIVIDE EM UP INTO COLUMNS

# %%
import os
import pandas as pd

# Specify the folder path where the CSV files are located
input_folder_path = "radar1"

# Specify the folder path to save the output CSVs
output_folder_path = "radar2"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Get a list of all files in the input folder
file_list = os.listdir(input_folder_path)

# Iterate over each file in the folder
for file_name in file_list:
    if file_name.endswith(".csv"):  # Process only CSV files
        input_file_path = os.path.join(input_folder_path, file_name)
        output_file_path = os.path.join(output_folder_path, file_name)
        
        df = pd.read_csv(input_file_path)
        second_column = df.iloc[:, 1]  # Assuming the second column index is 1 (0-indexed)
        values = second_column.tolist()
        print(len(values))

        with open(output_file_path, 'w') as file:
            for value in values:
                file.write(str(value))
                file.write('\n')
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# ...

# %% [markdown]
# ADD LABELS FOR EXISTING DATA [GETS REMOVED]

# %%
import os
import pandas as pd

# Specify the folder path where the CSV files are located
input_folder_path = "radar2"

# Specify the folder path to save the output CSVs
output_folder_path = "radar3"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Get a list of all files in the input folder
file_list = os.listdir(input_folder_path)

# Iterate over each file in the folder
for file_name in file_list:
    if file_name.endswith(".csv"):  # Process only CSV files
        input_file_path = os.path.join(input_folder_path, file_name)
        output_file_path = os.path.join(output_folder_path, file_name)

        # Read the existing CSV data
        df = pd.read_csv(input_file_path)

        # Create a new DataFrame with the new column
        new_column = pd.DataFrame({
            'Range': ['Azimuth', 'VrelRad', 'RCS', 'RangeVar', 'VrelRadVar', 'AzimuthVar', 'SNR']
        })

        # Concatenate the new column with the existing DataFrame
        df = pd.concat([new_column, df], axis=1)

        # Write the updated DataFrame to the output CSV file
        df.to_csv(output_file_path, index=False)
